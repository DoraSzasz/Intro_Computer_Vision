# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
width = 610
height = 610

# %%
sigma=10

# %%
noise_img=np.random.normal(loc=0, scale=1, size=(width,height)) * sigma

# %%
print(noise_img)
# Out:
# [[  7.86560314   3.27933087  13.05233826 ...  -3.73976302   5.37817276
#     2.1598092 ]
#  [ -4.95888342  -8.33043123 -10.52425186 ...  10.44480139   7.92572088
#   -11.70096724]
#  [ -7.58022715  13.63557846   7.79001588 ...  -9.20990526  12.17030252
#     4.09466771]
#  ...
#  [ -0.03716246   8.74986475  -2.61236043 ...  -0.99075085   1.65717621
#    -0.69433823]
#  [-14.27779276  -9.12981083  16.71221078 ...   9.96452759   5.15233087
#     7.93751835]
#  [-10.69692359  -8.46045126  18.34495406 ...   4.13533482 -14.19282389
#    11.58552618]]

# %%
plt.imshow(noise_img,cmap='gray', vmin=0, vmax=10)
plt.colorbar()

# %%
from PIL import Image
img = Image.open('saturn.jpg').convert('L')
plt.imshow(img, cmap = 'gray')
plt.colorbar()
img.size
# Out:
# (610, 610)

# %%
import cv2 as cv
img_cv = cv.imread('saturn.jpg')

# %%
result_img = img + noise_img

# %%
plt.imshow(result_img, cmap = 'gray', vmin=0, vmax=255)
plt.colorbar()

# %%
plt.plot(img_cv[400,:])
# Out:
# [<matplotlib.lines.Line2D at 0x24849dd2eb8>,
#  <matplotlib.lines.Line2D at 0x24849ddb0b8>,
#  <matplotlib.lines.Line2D at 0x24849ddb208>]

# %%
plt.plot(result_img[400,:])
