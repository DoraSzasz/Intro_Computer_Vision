# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
width = 610
height = 610

# %%
sigma=10

# %%
noise_img=np.random.normal(loc=0, scale=1, size=(width,height)) * sigma

# %%
print(noise_img)
# Out:
# [[-3.83310848e+00 -1.06824746e+01  6.77527342e+00 ... -5.53553293e+00
#   -4.61513903e+00  1.64800341e+01]
#  [-4.82628111e+00 -5.20959335e+00 -1.26925939e+01 ...  9.71895942e+00
#    5.39368333e-01 -3.54406820e+00]
#  [ 1.06529905e+01 -5.88201121e-03 -1.57292587e+00 ... -1.25851088e+01
#   -1.02718602e+01 -1.91310258e+01]
#  ...
#  [-9.23433201e+00 -4.52699197e+00 -6.89451373e+00 ...  6.67547754e+00
#   -1.80076700e+01  1.36027239e+01]
#  [-9.32308733e-01 -7.53256637e+00  7.02502586e+00 ... -4.99679045e-01
#    2.03627499e+00  1.94021598e+00]
#  [-1.90377528e+00 -8.07543634e+00 -7.42928605e+00 ... -1.39432263e+01
#    1.02129010e+01 -1.68757873e+01]]

# %%
plt.imshow(noise_img,cmap='gray', vmin=0, vmax=10)
plt.colorbar()

# %%
from PIL import Image
img = Image.open('saturn.jpg').convert('L')
plt.imshow(img, cmap = 'gray')
plt.colorbar()
img.size
# Out:
# (610, 610)

# %%
import cv2 as cv
img_cv = cv.imread('saturn.jpg')

# %%
result_img = img + noise_img

# %%
plt.imshow(result_img, cmap = 'gray', vmin=0, vmax=255)
plt.colorbar()

# %%
plt.plot(img_cv[400,:])
# Out:
# [<matplotlib.lines.Line2D at 0x216d5375208>,
#  <matplotlib.lines.Line2D at 0x216d53753c8>,
#  <matplotlib.lines.Line2D at 0x216d5375518>]

# %%
plt.plot(result_img[400,:])
