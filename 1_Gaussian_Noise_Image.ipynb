# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
width = 610
height = 610

# %%
sigma=10

# %%
noise_img=np.random.normal(loc=0, scale=1, size=(width,height)) * sigma

# %%
print(noise_img)
# Out:
# [[ -6.16460627   6.91617715 -14.25371812 ...  11.34801525  -6.435157
#    -9.00689454]
#  [ 16.96996761  -6.86445377  -5.47361583 ...  -8.41734614 -11.34350386
#   -10.77348514]
#  [ 17.60174597  -0.77449262  -2.88007614 ... -21.79535835  -8.57589726
#    10.36875769]
#  ...
#  [  8.53532896  -1.94894244 -10.63085002 ...  -8.04692774  12.23625606
#    12.74005603]
#  [-12.91458257  -2.50170052  -7.99708263 ...  -2.37886961  -8.36338545
#    -0.80917565]
#  [ -3.35905853   9.57161678  -3.39844027 ...   8.59454084  14.5386273
#   -14.92404101]]

# %%
plt.imshow(noise_img,cmap='gray', vmin=0, vmax=10)
plt.colorbar()

# %%
from PIL import Image
img = Image.open('saturn.jpg').convert('L')
plt.imshow(img, cmap = 'gray')
plt.colorbar()
img.size
# Out:
# (610, 610)

# %%
result_img = img + noise_img

# %%
plt.imshow(result_img, cmap = 'gray', vmin=0, vmax=255)
plt.colorbar()
